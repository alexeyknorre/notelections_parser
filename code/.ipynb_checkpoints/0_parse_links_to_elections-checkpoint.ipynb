# %%
from bs4 import BeautifulSoup
import csv

with open("/Users/alex/Dropbox/R/notelections_parser/data/notelections_2015_2021_majorit.html") as fp:
    soup = BeautifulSoup(fp, "html.parser")
    
links = soup.find_all('li','list-group-item')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# /var/folders/lg/xdls39lx0hbf5g_mnssx1hr00000gn/T/ipykernel_18971/1414761362.py in <module>
#       3
#       4 with open("/Users/alex/Dropbox/R/notelections_parser/data/notelections_2015_2021_majorit.html") as fp:
# ----> 5     soup = BeautifulSoup(fp, "html.parser")
#       6
#       7 links = soup.find_all('li','list-group-item')
#
# /usr/local/lib/python3.9/site-packages/bs4/__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     307
#     308         if hasattr(markup, 'read'):        # It's a file-type object.
# --> 309             markup = markup.read()
#     310         elif len(markup) <= 256 and (
#     311                 (isinstance(markup, bytes) and not b'<' in markup)
#
# /usr/local/Cellar/python@3.9/3.9.6/Frameworks/Python.framework/Versions/3.9/lib/python3.9/codecs.py in decode(self, input, final)
#     320         # decode input (taking the buffer into account)
#     321         data = self.buffer + input
# --> 322         (result, consumed) = self._buffer_decode(data, self.errors, final)
#     323         # keep undecoded input until the next call
#     324         self.buffer = data[consumed:]
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xcd in position 477: invalid continuation byte

# %%
lst = []
region = ''
munic_title = ''

for i in links:
    
   region_div = i.span

   if region_div is not None:
        region = region_div.nobr.get_text()
    
   i = i.div
   if i is None:
       continue
    
   munic_title_div = i.div
   if i.div.get_text():
        munic_title = i.div.get_text() 


   link = i.div.next_sibling.a['href'].replace('®', '&reg')
   base_url = "http://notelections.online"
   link = base_url+link

   munic_elections_title = i.div.next_sibling.get_text()
    
   lst.append([munic_title, munic_elections_title, link, region])
    
import pandas as pd
df = pd.DataFrame(lst, columns=['munic_title','munic_elections_title','link','region'])
df.to_csv("/Users/alex/Dropbox/R/notelections_parser/data/notelections_majorit_parsed_links.csv", sep=',',index=False)

# %%
# Out:
#                                              munic_title  \
# 0                          Задонский муниципальный район
# 1                       Измалковский муниципальный район
# 2                       Чаплыгинский муниципальный район
# 3               муниципальный район "Заиграевский район"
# 4               муниципальный район "Заиграевский район"
# ...                                                  ...
# 52423  Виноградовский муниципальный округ Архангельск...
# 52424  Шенкурский муниципальный район Архангельской о...
# 52425  Иглинский район                               ...
# 52426  Иглинский район                               ...
# 52427                      Ленинский муниципальный район
#
#                                    munic_elections_title  \
# 0       Досрочные выборы главы сельского поселения Ве...
# 1       Досрочные выборы главы сельского поселения Из...
# 2       Досрочные Выборы Главы сельского поселения Ко...
# 3       Выборы главы муниципального образования город...
# 4       Выборы депутатов представительного органа мун...
# ...                                                  ...
# 52423   Выборы депутатов муниципального Собрания внов...
# 52424   Выборы депутатов муниципального Совета Шенкур...
# 52425   Дополнительные выборы  депутата Совета сельск...
# 52426   Дополнительные выборы  депутатов Совета сельс...
# 52427   Досрочные выборы главы Каршевитского сельског...
#
#                                                     link  \
# 0      http://notelections.online/region/izbirkom?act...
# 1      http://notelections.online/region/izbirkom?act...
# 2      http://notelections.online/region/izbirkom?act...
# 3      http://notelections.online/region/izbirkom?act...
# 4      http://notelections.online/region/izbirkom?act...
# ...                                                  ...
# 52423  http://notelections.online/region/izbirkom?act...
# 52424  http://notelections.online/region/izbirkom?act...
# 52425  http://notelections.online/region/izbirkom?act...
# 52426  http://notelections.online/region/izbirkom?act...
# 52427  http://notelections.online/region/izbirkom?act...
#
#                         region
# 0             Липецкая область
# 1             Липецкая область
# 2             Липецкая область
# 3           Республика Бурятия
# 4           Республика Бурятия
# ...                        ...
# 52423    Архангельская область
# 52424    Архангельская область
# 52425  Республика Башкортостан
# 52426  Республика Башкортостан
# 52427    Волгоградская область
#
# [52428 rows x 4 columns]

# %%
# Out:
# 99

# %%
# Out:
# 'Муниципальное образование Котельничский район'

# %%
# Out:
# '/region/izbirkom?action=show&vrn=4434019166411®ion=43&prver=0&pronetvd=null'

# %%
# Out:
# ' Досрочные выборы главы муниципального образования Сретенское сельское поселение Котельничского района Кировской области'
